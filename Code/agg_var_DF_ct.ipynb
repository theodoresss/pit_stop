# %%
import os
import os.path
import sqlite3 as sq3
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import numpy as np
import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt
import plotly
import plotly.express as px
import time

# %% [markdown]
# ```
# draft
# ```
# print(intlst(l-2).reshape(1, -1).shape)
# print(np.array(lpt[1:l]).reshape(1, -1).shape)
#
# if X.shape[0] != y.shape[0]:
#   print("X and y rows are mismatched, check dataset again")

# %%
def tb2df(name):
    cmd = f"SELECT * FROM {name}"
    return pd.read_sql(cmd, con)

def intlst(r):
    return np.array([item for item in range(0, r+1)])

# %%
con = sq3.connect("/Users/theo/Documents/GitHub/pit_stop/Data/F1_timingdata_2014_2019.sqlite")
cursor = con.cursor()
table = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", con)
print(table)
# Out:
#             name
# 0        drivers
# 1  starterfields
# 2          races
# 3    qualifyings
# 4           laps
# 5    retirements
# 6      fcyphases

# %%
laps=tb2df("laps")

# %%
rid = laps['race_id'].unique()
did = laps['driver_id'].unique()
lap0=laps
lap0['lpt_slp']=None

# %%
for r in rid:
    for d in did:
        lpt = laps.loc[(laps['race_id']==r) & (laps['driver_id']==d)]['laptime'].tolist()
        l=len(lpt)
        if l > 2:
            coef_lst=[None, None]
            for i in range(2,l):
                coef_lst.append(LinearRegression().fit(intlst(i-2).reshape(-1, 1), np.array(lpt[1:i])).coef_[0])
            lap1=lap0[(lap0['race_id']==r) & (lap0['driver_id']==d)].copy()
            lap1['lpt_slp']=coef_lst
            lap0.update(lap1)

# %%
lapa = lap0
lapa['dt_rank']=lapa['position']

# %%
pitst = lapa.loc[csvf['pitstopduration'] > 0]

# %%
pitst
# Out:
#         race_id  lapno  position  driver_id  laptime  racetime      gap  \
# 38          1.0    1.0      17.0       22.0  130.795   130.795   28.757
# 39          1.0    1.0      18.0       16.0  156.707   156.707   54.669
# 40          1.0    1.0      19.0       20.0  161.894   161.894   59.856
# 204         1.0   10.0      16.0       15.0  156.286  1038.096   78.704
# 215         1.0   11.0       9.0       10.0  117.843  1101.790   47.213
# ...         ...    ...       ...        ...      ...       ...      ...
# 133673    121.0   38.0       3.0       40.0  104.980  3944.580   24.819
# 133676    121.0   38.0       6.0       12.0  105.352  3966.548   46.787
# 133717    121.0   40.0       7.0        8.0  105.782  4208.112   85.135
# 133740    121.0   41.0      10.0       25.0  105.220  4326.769  101.816
# 133761    121.0   42.0      11.0        2.0  105.502  4434.759  107.653
#
#         interval compound  tireage  ... pitstopduration  nextcompound  \
# ...

# %%
lapa.loc[(lapa['race_id'] == 1) & (lapa['driver_id'] == 22)].tail(1)['position'].iloc[0]
# Out:
# 12.0

# %% [markdown]
# #pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)]['dt_rank']=
#
# #pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)]['position'] -=12
# #-lapa.loc[(lapa['race_id'] == 1) & (lapa['driver_id'] == 22)].tail(1)['position']
#
# dtr_lst=[]
#
# #pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)]['dt_rank'].iloc[0]=0
# #pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)]
#
#
# updt = pitst.loc[(pitst['race_id']==1) & (pitst['driver_id']==22)].copy()
# updt.iloc[0,-1]-=lapa.loc[(lapa['race_id'] == 1) & (lapa['driver_id'] == 22)].tail(1)['position'].iloc[0]
# pitst.update(updt)
# #p1=pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)].copy()
# #p1['dt_rank']-=12
# #pitst.update(p1)
# #p1
# #pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)][:, 'position']  = pitst.loc[(pitst['race_id'] == 1) & (pitst['driver_id'] == 22)]['position'].apply(lambda x: x - 12)
#
# #pitst.loc[(pitst['race_id']==1) & (pitst['driver_id']==22)]
# pitst.loc[(pitst['race_id']==1) & (pitst['driver_id']==22)]

# %% [markdown]
# final rank 12

# %%
for r in rid:
    for d in did:
        temp = pitst.loc[(pitst['race_id']==r) & (pitst['driver_id']==d)]
        l=len(temp)
        updt = temp.copy() 
        for i in range(l):
            updt.iloc[i,-1]-=lapa.loc[(lapa['race_id'] == r) & (lapa['driver_id'] == d)].tail(1)['position'].iloc[0]
        pitst.update(updt)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:5732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[col] = expressions.where(mask, this, that)

# %%
pitst
# Out:
#         race_id  lapno  position  driver_id  laptime  racetime      gap  \
# 38          1.0    1.0      17.0       22.0  130.795   130.795   28.757
# 39          1.0    1.0      18.0       16.0  156.707   156.707   54.669
# 40          1.0    1.0      19.0       20.0  161.894   161.894   59.856
# 204         1.0   10.0      16.0       15.0  156.286  1038.096   78.704
# 215         1.0   11.0       9.0       10.0  117.843  1101.790   47.213
# ...         ...    ...       ...        ...      ...       ...      ...
# 133673    121.0   38.0       3.0       40.0  104.980  3944.580   24.819
# 133676    121.0   38.0       6.0       12.0  105.352  3966.548   46.787
# 133717    121.0   40.0       7.0        8.0  105.782  4208.112   85.135
# 133740    121.0   41.0      10.0       25.0  105.220  4326.769  101.816
# 133761    121.0   42.0      11.0        2.0  105.502  4434.759  107.653
#
#         interval compound  tireage  ... pitstopduration  nextcompound  \
# ...

# %%
pitst['sc_pit']= np.where(pitst['dt_rank']<0, True, False)
# Out:
# <ipython-input-173-f455a9364ec6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pitst['sc_pit']= np.where(pitst['dt_rank']<0, True, False)

# %%
pitst.loc[pitst['sc_pit']==True]
# Out:
#         race_id  lapno  position  driver_id  laptime  racetime      gap  \
# 228         1.0   12.0       4.0        7.0  136.397  1211.071   22.225
# 231         1.0   12.0       7.0        6.0  143.494  1222.660   33.814
# 233         1.0   12.0       9.0        8.0  150.844  1230.872   42.026
# 660         1.0   37.0       2.0        4.0  112.635  3726.236   41.813
# 1029        2.0    2.0      18.0        6.0  116.550   241.353   22.028
# ...         ...    ...       ...        ...      ...       ...      ...
# 133359    121.0   22.0       9.0       11.0  107.583  2342.292   80.388
# 133407    121.0   24.0      17.0       45.0  109.673  2581.574  112.853
# 133445    121.0   26.0      15.0       35.0  106.816  2790.169  113.505
# 133566    121.0   32.0      16.0       44.0  107.796  3433.594  126.545
# 133717    121.0   40.0       7.0        8.0  105.782  4208.112   85.135
#
#         interval compound  tireage  ... nextcompound  startlapprog_vsc  \
# ...

# %%
pitst.to_csv("pit_stop.csv", index=False)

# %%
min(df['lpt_slp'])
# Out:
# nan

# %%
df=pd.read_csv("pit_stop.csv")

# %%
df
# Out:
#       race_id  lapno  position  driver_id  laptime  racetime      gap  \
# 0         1.0    1.0      17.0       22.0  130.795   130.795   28.757
# 1         1.0    1.0      18.0       16.0  156.707   156.707   54.669
# 2         1.0    1.0      19.0       20.0  161.894   161.894   59.856
# 3         1.0   10.0      16.0       15.0  156.286  1038.096   78.704
# 4         1.0   11.0       9.0       10.0  117.843  1101.790   47.213
# ...       ...    ...       ...        ...      ...       ...      ...
# 4425    121.0   38.0       3.0       40.0  104.980  3944.580   24.819
# 4426    121.0   38.0       6.0       12.0  105.352  3966.548   46.787
# 4427    121.0   40.0       7.0        8.0  105.782  4208.112   85.135
# 4428    121.0   41.0      10.0       25.0  105.220  4326.769  101.816
# 4429    121.0   42.0      11.0        2.0  105.502  4434.759  107.653
#
#       interval compound  tireage  ... startlapprog_vsc  endlapprog_vsc  \
# ...

# %%
df['lg_slp'] = np.log2(df['lpt_slp'] + 1 - min(df['lpt_slp']))

# %%
import plotly.graph_objects as go

import numpy as np

y = df['lg_slp']
fig = go.Figure(data=[go.Histogram(y=y)])
fig.show()
# Out:
# <div>                            <div id="89cf9d79-6578-4c51-b446-f5a2fc239623" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89cf9d79-6578-4c51-b446-f5a2fc239623")) {                    Plotly.newPlot(                        "89cf9d79-6578-4c51-b446-f5a2fc239623",                        [{"type": "histogram", "y": [null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, null, n
# ...
